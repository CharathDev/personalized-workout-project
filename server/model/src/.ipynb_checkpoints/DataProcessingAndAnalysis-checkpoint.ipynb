# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import re

# %%
df = pd.read_csv('../data/workout_variations.csv')

def parse_workout_column(workout_str):
    return ast.literal_eval(workout_str)

df['Workout'] = df['Workout'].apply(parse_workout_column)

# %%
df.head()
# Out:
#           Goals     Level  Days  Time                       Equipments Gender  \
# 0  Build Muscle  Beginner     5  45.0                   ['Bodyweight']   Male
# 1  Build Muscle  Beginner     3  45.0                   ['Bodyweight']   Male
# 2  Build Muscle  Beginner     5  35.0  ['Bodyweight', 'Exercise Ball']   Male
# 3  Build Muscle  Beginner     3  45.0                   ['Bodyweight']   Male
# 4  Build Muscle  Beginner     4  35.0                   ['Bodyweight']   Male
#
#                                              Workout
# 0  [[{'exercise': 'Wide Push Up', 'sets': 4, 'rep...
# 1  [[{'exercise': 'Diamond Push Up', 'sets': 4, '...
# 2  [[{'exercise': 'Diamond Push Up', 'sets': 4, '...
# 3  [[{'exercise': 'Wide Push Up', 'sets': 4, 'rep...
# 4  [[{'exercise': 'Diamond Push Up', 'sets': 4, '...

# %%
df.isna().sum()
# Out:
# Goals         0
# Level         0
# Days          0
# Time          0
# Equipments    0
# Gender        0
# Workout       0
# dtype: int64

# %%
sns.countplot(data=df, x='Goals')
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Build Muscle'),
#   Text(1, 0, 'Lose Fat'),
#   Text(2, 0, 'Increase Strength'),
#   Text(3, 0, 'General Fitness'),
#   Text(4, 0, 'Increase Endurance'),
#   Text(5, 0, 'Sports Performance')])

# %%
sns.countplot(data=df, x='Gender')
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1], [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
sns.countplot(data=df, x='Level')
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Beginner'), Text(1, 0, 'Advanced'), Text(2, 0, 'Intermediate')])

# %%
sns.countplot(data=df, y='Time')
# Out:
# <Axes: xlabel='count', ylabel='Time'>

# %%
sns.countplot(data=df, x='Days')
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, '1'),
#   Text(1, 0, '2'),
#   Text(2, 0, '3'),
#   Text(3, 0, '4'),
#   Text(4, 0, '5'),
#   Text(5, 0, '6'),
#   Text(6, 0, '7'),
#   Text(7, 0, '8')])

# %%
df.shape
# Out:
# (7640, 7)

# %%
df.Goals.unique()
# Out:
# array(['Build Muscle', 'Lose Fat', 'Increase Strength', 'General Fitness',
#        'Increase Endurance', 'Sports Performance'], dtype=object)

# %%
df.columns
# Out:
# Index(['Goals', 'Level', 'Days', 'Time', 'Equipments', 'Gender', 'Workout'], dtype='object')

# %%
exercise_set = set()

# Loop through each workout and each exercise in the workout
for workout in df['Workout']:
    for day in workout:
        for exercise in day:
            name = exercise['exercise'].lower()
            name = re.sub(r"[^a-z0-9\s]", "", name)
            exercise_set.add(name)

# Display the result
print(exercise_set)
# Out:
# {'dumbbell cuban press', 'seated dumbbell biceps curl', 'single arm band standing flys', 'lying leg curl', 'jack knives', 'machine shrugs', 'smith machine shrug', 'db shrugs', 'rope hammer curl', 'tricep cable pressdowns', 'calf press ', 'smith machine incline bench press', 'set 12', 'seated leg curl or romanian deadlift', 'dumbbell stiff leg deadlift', 'smith machine press  warmup 80', 'face pull', 'pullups', 'one arm machine row', 'rack pull  above the knee', 'incline bench barbell press', 'lateral jumps', 'heavy cheat curl negatives', 'wide push up', 'giant set feetelevated pushup closegrip pullup flat bench barbell press and bentover barbell row', 'superset front squat with dumbbell stiff leg deadlift', 'leg press   muscle', 'seated leg curl ', 'one arm cable row 313 rep timing', 'bent over two arm dumbbell row', 'standing cable crunch', 'dumbbell curl', '5a trx pikes', '12 mile run', 'triset  dumbbell pullover', 'standing curl', 'one arm seated dumbbell extension pump', 'barbell curls ', 'flutterkick', 'bent over reverse fly', 'cable side lateral raise', 'bench squat pause one second when sitting', 'single arm lateral machine raise', 'band goodmornings', '20 yards', 'cable incline front raise', 'trx suspension push up', 'seated french press', 'reverse grip barbell row', 'lying side crunch', 'shoulder swings', '45 of 1rm', 'bodyweight glute bridge', 'seated low cable row', 'overhead barbell shoulder shrug', 'weighted chin', 'skullcrushers 45 seconds rest between sets', '4', 'smith machine bicep curl', 'behind neck lat pulldown', 'kick backs', 'standing calf raise', 'one arm seated dumbbell extension', 'barbell reverse curls', 'dumbbell flys', 'week 8', 'weighted tricep dips', '1 arm hammer strength low row', 'bent over row 10 lighter than workout a', 'cable face pull', 'cable crunches', 'hill sprints', '4b kettlebell sumo squats', 'widegrip pullup warm up 2x12 on lat pull downs', 'back extensions', 'hanging knee raise', 'bb anterior loaded bulgarian split squat', 'stiff legged deadlift', 'single leg bulgarian split squat and single leg dumbbell calf raise', 'combo 2\njabcrossleft hookright leg roundhouse', 'flat bench dumbbell or barbell press', 'bench press  drop 5 cycle', 'close grip chin up', 'seated curl', 'barbell or dumbbell deadlift', 'goblet squats', 'bottom position seated military press  week 2', 'rope crunch', 'bent rows', 'neutral grip pullups', 'side lying dumbbell reverse fly ', 'cross body curl', 'dumbbell punches', 'single leg bodyweight glute bridge', 'skullcrusher and press combination  warmup 80', 'dumbbell side bend', 'alternating hammer grip front dumbbell raise', 'incline chest machine press ', 'standing glute kickback', 'elevated leg extension', 'bear crawls', 'single arm dumbbell push press', 'romanian deadlift or leg curl   muscle', 'incline bench press followed by pushups', 'dumbbell chest press ', 'muffin tops', 'conventional deadlift', 'barbell close grip upright row', 'ez bar preacher curl', 'ez bar bicep 21s', 'barbell rollouts', 'or back squats ', 'vertical leg press', 'rope cable triceps press', 'plank', 'rear delt fly', 'flat bench press', 'deep squats w a 3second pause at the bottom', 'power shrug', 'half waiter walks ', 'hand release push ups', 'lying barbell tricep extension', 'dumbbell flat bench chest flys', 'superset  hanging leg raises', 'trx trainer suspension row', 'front squat and romanian deadlift', 'reverse hyperextension', 'rope cable hammer curl', 'seated barbell curl 45 secs rest between sets', 'narrow push up', 'seated arnold press', 'slight incline neutral grip dumbbell press', 'dumbbell bench press ', 'smith machine incline tricep extension', 'plank right foot raises', 'reversegrip pulldowns', 'twisting decline dumbbell situps', 'standing band rotation', 'military press', 'bent over dumbbell flyes  working sets', 'cable crossovers to upper chest', 'bodyweight skull crushers', 'bent over reverse flyes', 'reverse cable curls', 'bike', '2300\nbed', '1a feet elevated pushups w ...

# %%
exercises = pd.DataFrame({'exercise': list(exercise_set)})

# %%
exercises.to_csv('../data/exercises_list.csv')
